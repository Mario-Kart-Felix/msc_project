# %%
import nltk
import pandas as pd
import glob
from normalization import normalize_corpus, parse_document
from nltk.corpus import sentiwordnet as swn



def analyze_sentiment_sentiwordnet_lexicon(review, verbose=False):
    # tokenize and POS tag text tokens
    text_tokens = nltk.word_tokenize(review)
    tagged_text = nltk.pos_tag(text_tokens)
    pos_score = neg_score = token_count = obj_score = 0
    # get wordnet synsets based on POS tags
    # # get sentiment scores if synsets are found
    for word, tag in tagged_text:
        ss_set = None
        if 'NN' in tag and len(list(swn.senti_synsets(word, 'n'))) != 0:
            ss_sets = list(swn.senti_synsets(word, 'n'))
            ss_set = ss_sets[0]
        elif 'VB' in tag and len(list(swn.senti_synsets(word, 'v'))) != 0:
            ss_sets = list(swn.senti_synsets(word, 'v'))
            ss_set = ss_sets[0]
        elif 'JJ' in tag and len(list(swn.senti_synsets(word, 'a'))) != 0:
            ss_sets = list(swn.senti_synsets(word, 'a'))
            ss_set = ss_sets[0]
        elif 'RB' in tag and len(list(swn.senti_synsets(word, 'r'))) != 0:
            ss_sets = list(swn.senti_synsets(word, 'r'))
            ss_set = ss_sets[0]
        # if senti-synset is found
        if ss_set:
            # add scores for all found synsets
            pos_score += ss_set.pos_score()
            neg_score += ss_set.neg_score()
            token_count += 1
            # aggregate final scores
    final_score = pos_score - neg_score
    norm_final_score = round(float(final_score) / token_count, 2)
    final_sentiment = 'positive' if norm_final_score >= 0 else 'negative'
    if verbose:
        norm_pos_score = round(float(pos_score) / token_count, 2)
        norm_neg_score = round(float(neg_score) / token_count, 2)
        # to display results in a nice table
        sentiment_frame = pd.DataFrame([[final_sentiment,
                                        norm_pos_score, 
                                        norm_neg_score,
                                        norm_final_score]],
                                        columns=pd.MultiIndex(levels=[['Sentiment Statistics:'],
                                        ['Predicted Sentiment',
                                        'Positive',
                                        'Negative',
                                        'Overall']],
                                        labels=[[0,0,0,0],
                                        [0,1,2,3]]))
        print(sentiment_frame)
        return final_sentiment

    #Using readlines

def positive_and_negative_statistics(review, verbose=False):
    # tokenize and POS tag text tokens
#    sent_tokens = nltk.sent_tokenize(review)
    number_of_positive_words = 0
    number_of_negative_words = 0
    for sentence in review:
        text_tokens = nltk.word_tokenize(sentence)
        tagged_text = nltk.pos_tag(text_tokens)
        pos_score = neg_score = token_count = obj_score = 0
        # get wordnet synsets based on POS tags
        # get sentiment scores if synsets are found
        for word, tag in tagged_text:
            ss_set = None
            if 'NN' in tag and len(list(swn.senti_synsets(word, 'n'))) != 0:
                ss_sets = list(swn.senti_synsets(word, 'n'))
                ss_set = ss_sets[0]
            elif 'VB' in tag and len(list(swn.senti_synsets(word, 'v'))) != 0:
                ss_sets = list(swn.senti_synsets(word, 'v'))
                ss_set = ss_sets[0]
            elif 'JJ' in tag and len(list(swn.senti_synsets(word, 'a'))) != 0:
                ss_sets = list(swn.senti_synsets(word, 'a'))
                ss_set = ss_sets[0]
            elif 'RB' in tag and len(list(swn.senti_synsets(word, 'r'))) != 0:
                ss_sets = list(swn.senti_synsets(word, 'r'))
                ss_set = ss_sets[0]
            # if senti-synset is found
            if ss_set:
                # add scores for all found synsets
                pos_score += ss_set.pos_score()
                neg_score += ss_set.neg_score()
                token_count += 1
                # aggregate final scores
                final_score = pos_score - neg_score
                norm_final_score = round(float(final_score) / token_count, 2)
                final_sentiment = 'positive' if norm_final_score >= 0 else 'negative'
        if final_sentiment == 'positive':
            number_of_positive_words += 1
        else:
            number_of_negative_words += 1
    return 'Number of Positive Reviews:' + str(number_of_positive_words), 'Number of Negative Reviews:' + str(number_of_negative_words)
      
# Import the data set 
path = r'../data/raw/OpinosisDataset1.0_0/topics/'
allFiles = glob.glob(path + "/*.data")
for file_ in allFiles:
    with open(file_, "r") as f:
        reviews = f.readlines()
        print(positive_and_negative_statistics(reviews, verbose=True))
        print(analyze_sentiment_sentiwordnet_lexicon(' '.join(reviews), verbose=True))
# Out:
# ('Number of Positive Reviews:58', 'Number of Negative Reviews:9')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.13     0.07    0.07
# positive
# ('Number of Positive Reviews:62', 'Number of Negative Reviews:26')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.12     0.09    0.03
# positive
# ('Number of Positive Reviews:61', 'Number of Negative Reviews:29')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.07     0.06    0.01
# positive
# ('Number of Positive Reviews:52', 'Number of Negative Reviews:17')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.09     0.05    0.04
# positive
# ('Number of Positive Reviews:244', 'Number of Negative Reviews:89')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.08     0.05    0.02
# positive
# ('Number of Positive Reviews:119', 'Number of Negative Reviews:46')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.08     0.06    0.02
# positive
# ('Number of Positive Reviews:62', 'Number of Negative Reviews:104')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              negative     0.11     0.13   -0.03
# negative
# ('Number of Positive Reviews:31', 'Number of Negative Reviews:88')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              negative      0.1     0.14   -0.05
# negative
# ('Number of Positive Reviews:72', 'Number of Negative Reviews:27')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.08     0.06    0.03
# positive
# ('Number of Positive Reviews:39', 'Number of Negative Reviews:11')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.09     0.05    0.04
# positive
# ('Number of Positive Reviews:60', 'Number of Negative Reviews:20')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.13     0.09    0.04
# positive
# ('Number of Positive Reviews:47', 'Number of Negative Reviews:15')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.09     0.05    0.04
# positive
# ('Number of Positive Reviews:49', 'Number of Negative Reviews:15')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.11     0.08    0.03
# positive
# ('Number of Positive Reviews:89', 'Number of Negative Reviews:22')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive      0.1     0.05    0.05
# positive
# ('Number of Positive Reviews:40', 'Number of Negative Reviews:11')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive      0.1     0.05    0.05
# positive
# ('Number of Positive Reviews:119', 'Number of Negative Reviews:5')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.13     0.04     0.1
# positive
# ('Number of Positive Reviews:81', 'Number of Negative Reviews:34')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive      0.1     0.07    0.03
# positive
# ('Number of Positive Reviews:77', 'Number of Negative Reviews:17')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.14     0.07    0.06
# positive
# ('Number of Positive Reviews:77', 'Number of Negative Reviews:32')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.13     0.08    0.05
# positive
# ('Number of Positive Reviews:91', 'Number of Negative Reviews:35')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.11     0.08    0.03
# positive
# ('Number of Positive Reviews:298', 'Number of Negative Reviews:33')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.12     0.05    0.07
# positive
# ('Number of Positive Reviews:354', 'Number of Negative Reviews:58')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.11     0.05    0.06
# positive
# ('Number of Positive Reviews:128', 'Number of Negative Reviews:36')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.12     0.06    0.05
# positive
# ('Number of Positive Reviews:55', 'Number of Negative Reviews:8')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.11     0.06    0.06
# positive
# ('Number of Positive Reviews:74', 'Number of Negative Reviews:23')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.09     0.06    0.03
# positive
# ('Number of Positive Reviews:44', 'Number of Negative Reviews:7')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.12     0.06    0.06
# positive
# ('Number of Positive Reviews:45', 'Number of Negative Reviews:6')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.12     0.07    0.05
# positive
# ('Number of Positive Reviews:70', 'Number of Negative Reviews:30')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.09     0.06    0.03
# positive
# ('Number of Positive Reviews:116', 'Number of Negative Reviews:27')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive      0.1     0.05    0.05
# positive
# ('Number of Positive Reviews:58', 'Number of Negative Reviews:14')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.15     0.09    0.07
# positive
# ('Number of Positive Reviews:182', 'Number of Negative Reviews:84')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.11     0.09    0.03
# positive
# ('Number of Positive Reviews:124', 'Number of Negative Reviews:32')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.12     0.07    0.05
# positive
# ('Number of Positive Reviews:391', 'Number of Negative Reviews:184')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive      0.1     0.08    0.02
# positive
# ('Number of Positive Reviews:48', 'Number of Negative Reviews:15')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.08     0.05    0.02
# positive
# ('Number of Positive Reviews:79', 'Number of Negative Reviews:25')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.09     0.06    0.04
# positive
# ('Number of Positive Reviews:51', 'Number of Negative Reviews:7')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.11     0.05    0.06
# positive
# ('Number of Positive Reviews:127', 'Number of Negative Reviews:51')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.09     0.06    0.03
# positive
# ('Number of Positive Reviews:41', 'Number of Negative Reviews:40')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive      0.1      0.1    -0.0
# positive
# ('Number of Positive Reviews:109', 'Number of Negative Reviews:35')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.11     0.07    0.04
# positive
# ('Number of Positive Reviews:123', 'Number of Negative Reviews:47')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive      0.1     0.07    0.04
# positive
# ('Number of Positive Reviews:150', 'Number of Negative Reviews:48')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive      0.1     0.06    0.04
# positive
# ('Number of Positive Reviews:53', 'Number of Negative Reviews:33')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive      0.1     0.09    0.01
# positive
# ('Number of Positive Reviews:95', 'Number of Negative Reviews:6')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.15     0.04    0.11
# positive
# ('Number of Positive Reviews:47', 'Number of Negative Reviews:22')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.07     0.05    0.01
# positive
# ('Number of Positive Reviews:95', 'Number of Negative Reviews:29')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.08     0.05    0.03
# positive
# ('Number of Positive Reviews:285', 'Number of Negative Reviews:33')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.13     0.06    0.07
# positive
# ('Number of Positive Reviews:155', 'Number of Negative Reviews:49')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.13     0.08    0.05
# positive
# ('Number of Positive Reviews:81', 'Number of Negative Reviews:74')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              negative     0.08     0.09   -0.01
# negative
# ('Number of Positive Reviews:46', 'Number of Negative Reviews:20')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.06     0.05    0.01
# positive
# ('Number of Positive Reviews:183', 'Number of Negative Reviews:32')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive      0.1     0.05    0.06
# positive
# ('Number of Positive Reviews:62', 'Number of Negative Reviews:27')
#   Sentiment Statistics:
#     Predicted Sentiment Positive Negative Overall
# 0              positive     0.11     0.06    0.04
# positive

# %%
import nltk
import pandas as pd
import glob
from nltk.corpus import sentiwordnet as swn

#Using readlines

def positive_and_negative_statistics(review, verbose=False):
    # tokenize and POS tag text tokens
#    sent_tokens = nltk.sent_tokenize(review)
    number_of_positive_words = 0
    number_of_negative_words = 0
    for sentence in review:
        text_tokens = nltk.word_tokenize(sentence)
        tagged_text = nltk.pos_tag(text_tokens)
        pos_score = neg_score = token_count = obj_score = 0
        # get wordnet synsets based on POS tags
        # get sentiment scores if synsets are found
        for word, tag in tagged_text:
            ss_set = None
            if 'NN' in tag and len(list(swn.senti_synsets(word, 'n'))) != 0:
                ss_sets = list(swn.senti_synsets(word, 'n'))
                ss_set = ss_sets[0]
            elif 'VB' in tag and len(list(swn.senti_synsets(word, 'v'))) != 0:
                ss_sets = list(swn.senti_synsets(word, 'v'))
                ss_set = ss_sets[0]
            elif 'JJ' in tag and len(list(swn.senti_synsets(word, 'a'))) != 0:
                ss_sets = list(swn.senti_synsets(word, 'a'))
                ss_set = ss_sets[0]
            elif 'RB' in tag and len(list(swn.senti_synsets(word, 'r'))) != 0:
                ss_sets = list(swn.senti_synsets(word, 'r'))
                ss_set = ss_sets[0]
            # if senti-synset is found
            if ss_set:
                # add scores for all found synsets
                pos_score += ss_set.pos_score()
                neg_score += ss_set.neg_score()
                token_count += 1
                # aggregate final scores
                final_score = pos_score - neg_score
                norm_final_score = round(float(final_score) / token_count, 2)
                final_sentiment = 'positive' if norm_final_score >= 0 else 'negative'
        if final_sentiment == 'positive':
                    number_of_positive_words += 1
        else:
            number_of_negative_words += 1
    return ('Number of Positive Reviews:' + str(number_of_positive_words), 'Number of Negative Reviews:' + str(number_of_negative_words))
      
                
        

    
# Import the data set 
path = r'../data/raw/OpinosisDataset1.0_0/topics/'
allFiles = glob.glob(path + "/*.data")
for file_ in allFiles:
    with open(file_, "r") as f:
        review = f.readlines()
        print(positive_and_negative_statistics(review, verbose=True))
# Out:
# ('Number of Positive Reviews:58', 'Number of Negative Reviews:9')
# ('Number of Positive Reviews:62', 'Number of Negative Reviews:26')
# ('Number of Positive Reviews:61', 'Number of Negative Reviews:29')
# ('Number of Positive Reviews:52', 'Number of Negative Reviews:17')
# ('Number of Positive Reviews:244', 'Number of Negative Reviews:89')
# ('Number of Positive Reviews:119', 'Number of Negative Reviews:46')
# ('Number of Positive Reviews:62', 'Number of Negative Reviews:104')
# ('Number of Positive Reviews:31', 'Number of Negative Reviews:88')
# ('Number of Positive Reviews:72', 'Number of Negative Reviews:27')
# ('Number of Positive Reviews:39', 'Number of Negative Reviews:11')
# ('Number of Positive Reviews:60', 'Number of Negative Reviews:20')
# ('Number of Positive Reviews:47', 'Number of Negative Reviews:15')
# ('Number of Positive Reviews:49', 'Number of Negative Reviews:15')
# ('Number of Positive Reviews:89', 'Number of Negative Reviews:22')
# ('Number of Positive Reviews:40', 'Number of Negative Reviews:11')
# ('Number of Positive Reviews:119', 'Number of Negative Reviews:5')
# ('Number of Positive Reviews:81', 'Number of Negative Reviews:34')
# ('Number of Positive Reviews:77', 'Number of Negative Reviews:17')
# ('Number of Positive Reviews:77', 'Number of Negative Reviews:32')
# ('Number of Positive Reviews:91', 'Number of Negative Reviews:35')
# ('Number of Positive Reviews:298', 'Number of Negative Reviews:33')
# ('Number of Positive Reviews:354', 'Number of Negative Reviews:58')
# ('Number of Positive Reviews:128', 'Number of Negative Reviews:36')
# ('Number of Positive Reviews:55', 'Number of Negative Reviews:8')
# ('Number of Positive Reviews:74', 'Number of Negative Reviews:23')
# ('Number of Positive Reviews:44', 'Number of Negative Reviews:7')
# ('Number of Positive Reviews:45', 'Number of Negative Reviews:6')
# ('Number of Positive Reviews:70', 'Number of Negative Reviews:30')
# ('Number of Positive Reviews:116', 'Number of Negative Reviews:27')
# ('Number of Positive Reviews:58', 'Number of Negative Reviews:14')
# ('Number of Positive Reviews:182', 'Number of Negative Reviews:84')
# ('Number of Positive Reviews:124', 'Number of Negative Reviews:32')
# ('Number of Positive Reviews:391', 'Number of Negative Reviews:184')
# ('Number of Positive Reviews:48', 'Number of Negative Reviews:15')
# ('Number of Positive Reviews:79', 'Number of Negative Reviews:25')
# ('Number of Positive Reviews:51', 'Number of Negative Reviews:7')
# ('Number of Positive Reviews:127', 'Number of Negative Reviews:51')
# ('Number of Positive Reviews:41', 'Number of Negative Reviews:40')
# ('Number of Positive Reviews:109', 'Number of Negative Reviews:35')
# ('Number of Positive Reviews:123', 'Number of Negative Reviews:47')
# ('Number of Positive Reviews:150', 'Number of Negative Reviews:48')
# ('Number of Positive Reviews:53', 'Number of Negative Reviews:33')
# ('Number of Positive Reviews:95', 'Number of Negative Reviews:6')
# ('Number of Positive Reviews:47', 'Number of Negative Reviews:22')
# ('Number of Positive Reviews:95', 'Number of Negative Reviews:29')
# ('Number of Positive Reviews:285', 'Number of Negative Reviews:33')
# ('Number of Positive Reviews:155', 'Number of Negative Reviews:49')
# ('Number of Positive Reviews:81', 'Number of Negative Reviews:74')
# ('Number of Positive Reviews:46', 'Number of Negative Reviews:20')
# ('Number of Positive Reviews:183', 'Number of Negative Reviews:32')
# ('Number of Positive Reviews:62', 'Number of Negative Reviews:27')

# %%
# Out:
# ('Number of Positive Reviews:57', 'Number of Negative Reviews:8')
# ('Number of Positive Reviews:62', 'Number of Negative Reviews:26')
# ('Number of Positive Reviews:59', 'Number of Negative Reviews:29')
# ('Number of Positive Reviews:48', 'Number of Negative Reviews:16')
# ('Number of Positive Reviews:226', 'Number of Negative Reviews:87')
# ('Number of Positive Reviews:117', 'Number of Negative Reviews:45')
# ('Number of Positive Reviews:61', 'Number of Negative Reviews:103')
# ('Number of Positive Reviews:30', 'Number of Negative Reviews:87')
# ('Number of Positive Reviews:69', 'Number of Negative Reviews:27')
# ('Number of Positive Reviews:39', 'Number of Negative Reviews:10')
# ('Number of Positive Reviews:58', 'Number of Negative Reviews:20')
# ('Number of Positive Reviews:45', 'Number of Negative Reviews:14')
# ('Number of Positive Reviews:49', 'Number of Negative Reviews:14')
# ('Number of Positive Reviews:88', 'Number of Negative Reviews:21')
# ('Number of Positive Reviews:40', 'Number of Negative Reviews:11')
# ('Number of Positive Reviews:117', 'Number of Negative Reviews:5')
# ('Number of Positive Reviews:78', 'Number of Negative Reviews:33')
# ('Number of Positive Reviews:76', 'Number of Negative Reviews:17')
# ('Number of Positive Reviews:76', 'Number of Negative Reviews:32')
# ('Number of Positive Reviews:88', 'Number of Negative Reviews:33')
# ('Number of Positive Reviews:264', 'Number of Negative Reviews:30')
# ('Number of Positive Reviews:349', 'Number of Negative Reviews:58')
# ('Number of Positive Reviews:123', 'Number of Negative Reviews:35')
# ('Number of Positive Reviews:53', 'Number of Negative Reviews:7')
# ('Number of Positive Reviews:72', 'Number of Negative Reviews:21')
# ('Number of Positive Reviews:44', 'Number of Negative Reviews:7')
# ('Number of Positive Reviews:41', 'Number of Negative Reviews:4')
# ('Number of Positive Reviews:68', 'Number of Negative Reviews:30')
# ('Number of Positive Reviews:115', 'Number of Negative Reviews:27')
# ('Number of Positive Reviews:56', 'Number of Negative Reviews:14')
# ('Number of Positive Reviews:175', 'Number of Negative Reviews:83')
# ('Number of Positive Reviews:124', 'Number of Negative Reviews:32')
# ('Number of Positive Reviews:389', 'Number of Negative Reviews:183')
# ('Number of Positive Reviews:45', 'Number of Negative Reviews:15')
# ('Number of Positive Reviews:72', 'Number of Negative Reviews:23')
# ('Number of Positive Reviews:49', 'Number of Negative Reviews:7')
# ('Number of Positive Reviews:123', 'Number of Negative Reviews:48')
# ('Number of Positive Reviews:40', 'Number of Negative Reviews:40')
# ('Number of Positive Reviews:103', 'Number of Negative Reviews:35')
# ('Number of Positive Reviews:121', 'Number of Negative Reviews:46')
# ('Number of Positive Reviews:148', 'Number of Negative Reviews:47')
# ('Number of Positive Reviews:51', 'Number of Negative Reviews:29')
# ('Number of Positive Reviews:85', 'Number of Negative Reviews:6')
# ('Number of Positive Reviews:45', 'Number of Negative Reviews:21')
# ('Number of Positive Reviews:86', 'Number of Negative Reviews:28')
# ('Number of Positive Reviews:280', 'Number of Negative Reviews:32')
# ('Number of Positive Reviews:154', 'Number of Negative Reviews:49')
# ('Number of Positive Reviews:78', 'Number of Negative Reviews:73')
# ('Number of Positive Reviews:44', 'Number of Negative Reviews:20')
# ('Number of Positive Reviews:167', 'Number of Negative Reviews:28')
# ('Number of Positive Reviews:61', 'Number of Negative Reviews:27')
